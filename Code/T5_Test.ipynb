# %%
# This script loads T5 model and test and create slovenian paraphrases

# %%
# !pip install transformers
# !pip install SentencePiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SentencePiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
import pandas as pd
import numpy as np
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch
from google.colab import drive

# %%
# Set how many sentences to paraphrase and how many paraphrases for eaac sentence

numberOfSentences = 100
numberOfParaphrases = 10

drive.mount('/content/gdrive/', force_remount=True)
pathToModel = '/content/gdrive/MyDrive/NLPProject/paraphrasing/model/'
# Out:
# Mounted at /content/gdrive/

# %%
# Reads sentences from Excel file
testSentences = pd.read_excel('/content/gdrive/MyDrive/NLPProject/paraphrasing/TestSentences.xlsx')
testSentences = testSentences.values.tolist()
testSentences = [i[0] for i in testSentences]
testSentences = testSentences[:numberOfSentences] 
print(len(testSentences))
# Out:
# 100

# %%
# Loads a model and tokeinzer

tokenizer = T5Tokenizer.from_pretrained("cjvt/t5-sl-small")
model = T5ForConditionalGeneration.from_pretrained(pathToModel)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32000, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32000, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32000, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-7): 7 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#               (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#               (wo): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=32000, bias=False)
# )

# %%
outputTable = pd.DataFrame(index=range(len(testSentences)),columns=range(numberOfParaphrases+1))


for i in range(len(testSentences)):
    text =  "parafraza: " + testSentences[i]
    max_len = 256
    vrstica = [testSentences[i]]
    outputTable[0][i] = testSentences[i]
    encoding = tokenizer.encode_plus(text, padding='max_length', return_tensors="pt")
    input_ids, attention_masks = encoding["input_ids"].to(device), encoding["attention_mask"].to(device)
    
    beam_outputs = model.generate(
        input_ids=input_ids, attention_mask=attention_masks,
        do_sample=True,
        max_length=256,
        top_k=120,
        top_p=0.98,
        early_stopping=True,
        num_return_sequences=numberOfParaphrases
    )
    

    print ("\nOriginal sentence:")
    print (testSentences[i])
    print ("\n")
    print ("Paraphrased sentences:")
    final_outputs =[]
    for beam_output in beam_outputs:
        sent = tokenizer.decode(beam_output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
        if sent.lower() != testSentences[i].lower() and sent not in final_outputs:
            final_outputs.append(sent)
            
    for a, final_output in enumerate(final_outputs):
        print("{}: {}".format(a, final_output))
        outputTable[a+1][i] = final_output
        vrstica.append(final_output)
        
    print("\n-----------------------\n")
# Out:
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Original sentence:
# Vsaka občinska volilna komisija mora v občini določiti najmanj eno volišče, ki je dostopno invalidom.
#
#
# Paraphrased sentences:
# 0: Vsaka občinska volilna komisija v občini mora določiti najmanj eno volišče, ki je brezplačno za invalide.
# 1: Vsaka občinska volilna komisija v občini mora določiti vsaj eno volišče, ki je brezplačno za invalide.
#
# -----------------------
#
#
# Original sentence:
# Če nič ne delajo, ne morejo nič narediti narobe in jih nihče ne more pribijati na križ, pravi Simič.
#
#
# Paraphrased sentences:
# 0: Če nič ne delajo, ne morejo ničesar narediti narobe in jih nihče ne more pribijati na križ, pravi Simič.
# 1: Če nič ne delajo, ne morejo nič narediti narobe, in jih nihče ne more pribijati na križ, pravi Simič.
#
# -----------------------
#
#
# Original sentence:
# Po svoji naravi je svetovljanka in se znajde v katerikoli deželi, povsod je lahko doma.
#
#
# Paraphrased sentences:
# 0: Po svojem značaju je svetovljan in je lahko doma.
# 1: Po svojem značaju je svetovljan in lahko je doma.
# 2: Po svoji naravi je svetovljan in se lahko po meri vsakogar najde doma.
# 3: Po svoji naravi je svetovljan in se lahko brez težav odpravi na pot.
# 4: Po svoji naravi je svetovljan in živi v vsaki deželi, kjer je lahko doma.
# 5: Po svoji naravi je svetovljan in lahko je doma.
# 6: Po svoji naravi je svetovljan in živi v vseh deželah sveta, kjer je lahko doma.
# 7: Po svoji naravi je svetovljan in je lahko doma.
#
# -----------------------
#
#
# Original sentence:
# Zgodba z Oswaldom je bila namreč na tako trhlih nogah, da so ji v resnici verjeli samo največji naivneži.
#
#
# Paraphrased sentences:
# 0: Zgodba z Oswaldom je bila tako na trhlih nogah, da so jo v resnici verjeli le največji naivni naivni.
# 1: Zgodba z Oswaldom je bila tako na trhlih nogah, da so jo v resnici verjeli le največji naivni naivci.
# 2: Zgodba z Oswaldom je bila tako na trhlih nogah, da so ji v resnici verjeli le največji naivni naivci.
# 3: Zgodba z Oswaldom je bila tako na trhlih nogah, da so ji v resnici verjeli le največji naivni naivni.
#
# -----------------------
#
#
# Original sentence:
# Ameriški psihologi, jezikoslovci in sociologi na grozo politikov ugotavljajo, da je celo v slengu mladih prišlo do korenitih sprememb.
#
#
# Paraphrased sentences:
# 0: Ameriški psihologi, jezikoslovci in sociologi opažajo, da je celo v slengu mladih prišlo do korenitih sprememb.
#
# -----------------------
#
#
# Original sentence:
# Ni se mi dalo več seksati, ne vem zakaj, ženske so se mi nekako upirale, celo planika vseh žensk Ariana.
#
#
# Paraphrased sentences:
# 0: sploh mi ni bilo treba več seksati, ne vem, zakaj, celo platnica vseh žensk Ariana.
# 1: sploh mi ni bilo treba več hoditi v posteljo, nekako mi je celo grozilo, celo pladnica vseh ženskih aktov Ariana.
# 2: sploh mi ni bilo treba več seksati, ne vem, zakaj, celo pladnica vseh moških Ariana.
# 3: sploh mi ni uspelo več seksati, ne vem, zakaj, celo platnica vseh vseh žensk Ariana.
# 4: sploh mi ni uspelo več seksati, ne vem, zakaj, celo pladnica vseh moških Ariana.
# 5: sploh mi ni dalo več seksati, ne vem, zakaj, celo pladnica vseh moških Ariane.
# 6: sploh mi ni bilo treba več seksati, ne vem, zakaj, celo platorka vseh ženskih aktov Ariane.
# 7: sploh mi ni dalo več seksati, ne vem, zakaj, celo platnica vseh vseh žensk Ariana.
#
# -----------------------
#
#
# Original sentence:
# Pravzaprav je že gotova, samo preproga in zavese še manjkajo.
#
#
# Paraphrased sentences:
# 0: Pravzaprav je že gotova, samo preproga in zavese manjka.
# 1: Pravzaprav je že gotova, vendar še vedno manjkajoča preproga in zavese.
# 2: Pravzaprav je gotova, vendar še vedno manjka nekaj preproge in zaves.
# 3: Pravzaprav je že gotova, vendar še vedno manjka nekaj preproge in zaves.
#
# -----------------------
#
#
# Original sentence:
# Praznujeva ga z obiskom kina, na sprehodu po okolici naše domače Višnje Gore ali s skupno kavico.
#
#
# Paraphrased sentences:
# 0: Praznujem ga z obiskom kina, na sprehodu po okolici naše Višnje Gore ali s skupno piknico.
# 1: Praznujem ga z obiskom kina, na sprehodu po okolici naše Višnje Gore ali s skupno večerjo.
# 2: Osnutek iz tega naslova je obisk kina, na sprehodu po okolici naše Višnje Gore ali s skupno kavico.
# 3: Osnutek si lahko ogledate z obiskom kina, sprehoda po okolici naše Višnje Gore ali s skupno kavico.
# 4: Osnutek iz tega izhaja iz obiska kinematografije, na sprehodu po okolici naše Višnje Gore ali s skupno kuhanjem.
# 5: Osnutek si pridobim z obiskom kina, na sprehodu po okolici naše Višnje Gore ali s skupno kavico.
# 6: Osnutek iz tega izhaja iz obiska kinematoka, na sprehodu po okolici naše Višnje Gore ali s skupno piknico.
# 7: Praznujem jo z obiskom kina, na sprehodu po okolici naše Višnje Gore ali s skupno kavico.
# 8: Osnutek iz tega izhaja iz obiska kinematografije, na sprehodu po okolici naše Višnje Gore ali s skupno prigri bombnico.
# 9: Preznujem jo z obiskom kina, na sprehodu po okolici naše Višnje Gore ali s skupno kavico.
#
# -----------------------
#
#
# Original sentence:
# Sledilo je uigravanje novega materiala in posebni promocijski nastopi (show-case), ki so namenjeni predstavnikom gramofonskih hiš.
#
#
# Paraphrased sentences:
# 0: Temu je sledilo urjenje novega materiala in posebni promocijski nastopi, ki so namenjeni predstavnikom gramofonskih hiš.
# 1: Nato se je urjenje novega materiala in posebni promocijski nastopi, ki so namenjeni predstavnikom gramofonskih hiš.
# 2: Temu je sledilo urjenje novega materiala in posebne predstavitve, ki so jih namenili predstavnikom gramofonskih hiš.
# 3: Nato se je urjenje novega materiala in posebni promocijski nastopi, namenjeni predstavnikom gramofonskih hiš.
# 4: Nato se je urjenje materiala in posebni promocijski nastopi, ki so namenjeni predstavnikom gramofonskih hiš.
# 5: Nato se je urjenje novih materialov in posebni promocijski nastopi, ki so namenjeni predstavnikom gramofonskih hiš.
# 6: Nato se je urjenje materiala in posebni promocijski nastopi, namenjeni predstavnikom gramofonskih hiš.
# 7: Nato je sledilo urjenje novega materiala in posebni tržni nastopi, ki so namenjeni predstavnikom gramofonskih hiš.
#
# -----------------------
#
#
# Original sentence:
# Tam se bomo v petek in v soboto pomerili z vrsto Bratislave.
#
#
# Paraphrased sentences:
# 0: V petek in soboto se bomo pomerili z vrsto Bratislava.
# 1: V petek in v soboto se bomo pomerili z vrsto Bratislava.
# 2: V petek in soboto se bomo pomerili z vrsto Bratislave.
#
# -----------------------
#
#
# Original sentence:
# McCourt je v Dublinu končal Belvedere College, doktoriral pa leta 1991 na University College .
#
#
# Paraphrased sentences:
# 0: McCourt je v Dublinu končal Belvedere College in doktoriral leta 1991 na Cambridgeu.
# 1: McCourt je v Dublinu končal Belvedere College in diplomiral leta 1991 na Cambridgeu.
# 2: McCourt je v Dublinu končal Belvedere College in diplomiral leta 1991 na Camdere College.
# 3: McCourt je v Dublinu končal Belvedere College, leta 1991 pa je na univerzo prišel do izraza.
# 4: McCourt je končal Belvedere College v Dublinu in doktoriral leta 1991 na Cambridgeu.
#
# -----------------------
#
#
# Original sentence:
# Pod točilnim pultom vidimo Novice malega Pariza, ki so jih času primerno bolj ali manj posvetili ptičji gripi.
#
#
# Paraphrased sentences:
# 0: Pod točilnim pultom vidimo novice iz mesta, ki so bile takrat najbolj ali manj posvečene ptičjim gripam.
# 1: Pod točilnim pultom vidimo novice iz mesta, ki so bile takrat še vedno posvečene ptičjim gripam.
# 2: Pod točilnim pultom vidimo novice iz velikega Pariza, ki so bile prvotno bolj ali manj posvečene ptičjim gripam.
# 3: Pod točilnim pultom vidimo novice iz mesta, ki so bile takrat nekoliko prehladne.
# 4: Pod točilnim pultom vidimo novice iz mesta, ki so bile takrat nekoliko bolj ali manj posvečene ptičjim gripam.
# 5: Pod točilnim pultom vidimo novice iz živalskega vrta, ki so bile prvotno posvečene ptičjim gripam.
# 6: Pod točilnim pultom vidimo novice iz mesta, ki so bile prvotno posvečene ptičjim gripam.
#
# -----------------------
#
#
# Original sentence:
# Zagotovo pa ne bi imel nič proti, če bi v vlogi gosta nastopil tudi kateri od mojih pevskih partnerjev.
#
#
# Paraphrased sentences:
# 0: Zagotovo pa ne bi imel nič proti, če bi v vlogi gosta nastopil kateri od mojih pevskih kolegov.
# 1: Zagotovo pa ne bi imel nič proti, če bi v vlogi gostitelja nastopil kateri od mojih pevskih kolegov.
# 2: Zagotovo pa ne bi imel nič proti, če bi v vlogi gosta nastopil kakšen od mojih pevskih kolegov.
# 3: Zagotovo ne bi imel nič proti, če bi v vlogi gosta nastopil kateri od mojih pevskih kolegov.
# 4: zagotovo pa ne bi imel nič proti, če bi v vlogi gosta nastopil kateri od mojih pevskih kolegov.
# 5: Zagotovo ne bi imel nič proti, če bi v vlogi gosta nastopil kakšen od mojih pevskih kolegov.
#
# -----------------------
#
#
# Original sentence:
# Potrudila se bom, da ju bom redno jahala.
#
#
# Paraphrased sentences:
# 0: bom naredil dovolj zanju.
# 1: močno se bom potrudil, da bi ju redno jahal.
# 2: močno se bom potrudil, da ju bom redno jahala.
# 3: bom naredil najmanj dva meseca.
# 4: bom naredil dovolj, da ju bom redno jahal.
# 5: močno se bom potrudila, da bom redno jahala.
# 6: močno se bom potrudila, da bi ju redno merila.
# 7: močno se bom potrudila, da bi ju redno jahala.
# 8: bom naredil dovolj za ju bom redno jahala.
#
# -----------------------
#
#
# Original sentence:
# Zato jo je po opravljenem postopku njenega preizkusa sprejelo.
#
#
# Paraphrased sentences:
# 0: Zato ga je po uspešno prestali postopku njenega preizkusa.
# 1: Zato jo je po njegovem postopku njegovega preizkusa sprejelo.
# 2: Zato ga je po opravljenih postopkih njegovega preizkusa sprejelo.
# 3: Zato je po uspešno prestali preizkus.
# 4: Zato jo je po opravljenih postopkih z njim sprejelo.
# 5: Zato jo je po opravljenih storitvah tožilo.
# 6: Zato jo je po uspešno prestalo njegovo preverjanje.
# 7: Zato ga je po njegovem postopku njegovega preizkusa sprejelo.
# 8: Zato je po njegovem mnenju sledilo postopku njenega preizkusa.
#
# -----------------------
#
#
# Original sentence:
# Za Everest ste se torej odločili, ker to ni uspelo še nikomur?
#
#
# Paraphrased sentences:
# 0: Torej ste se odločili, da greš na Everest, ker vam ni uspelo še nikomur?
# 1: Torej ste se odločili, da izberete Everest, ker ti ni uspelo še nikomur?
# 2: Torej se odločite, da izberete Everest, ker vam ni uspelo še nikomur?
# 3: Torej se odločili, da greš na Everest, ker ti ni uspelo še nikomur?
# 4: Torej se je odločil, da se storite, ker vam ni uspelo še nikomur?
# 5: Torej se odločite, da greš na Everest, ker ti ni uspelo še nikomur?
# 6: Torej ste se odločili, da greš na Everest, ker ti ni uspelo še nikomur?
#
# -----------------------
#
#
# Original sentence:
# Lahko se zgolj vprašamo, ali je barva fasade odraz kulture bivanja.
#
#
# Paraphrased sentences:
# 0: Samo vprašanje barve fasade je lahko odraz kulture biva.
# 1: Samo vprašanje barve fasade je lahko pokazatelj kulture bivanja.
# 2: Samo vprašamo se lahko, ali je barva fasade odraz kulture družbe.
# 3: Samo vprašanje barve fasade je lahko pokazatelj kulture biva.
# 4: Samo vprašanje barve fasade je lahko odraz kulture bivanja.
# 5: Lahko se samo vprašamo, ali je barva fasade odraz kulture družbe.
#
# -----------------------
#
#
# Original sentence:
# Moški v uniformah je ne privlačijo.
#
#
# Paraphrased sentences:
# 0: Moški v uniformi niso privlačni.
# 1: Moški v uniformi ne privlačijo moškega.
# 2: Moški v uniformi nimajo uniform.
#
# -----------------------
#
#
# Original sentence:
# Pozna vse skrivnosti družine Montenegro in molči, saj skriva veliko bolečih podrobnosti.
#
#
# Paraphrased sentences:
# 0: Vedel je vse skrivnosti družine Montenegro in molčal, saj skriva veliko bolečih podrobnosti.
# 1: Ve vse skrivnosti družine Montenegro in molči, saj skriva veliko bolečih podrobnosti.
# 2: Vse skrivnosti družine Montenegro pozna in molči, saj skriva veliko bolečih podrobnosti.
# 3: Vse skrivnosti družine Montenegro vedra in molči, saj skriva veliko bolečih podrobnosti.
# 4: On pozna vse skrivnosti družine Montenegro in molči, saj skriva veliko bolečih podrobnosti.
#
# -----------------------
#
#
# Original sentence:
# ZAKAJ PA ŠEPETAŠ, MALI, SI ŠE V ŠOKU, KO SI ZVEDEL, DA BOŠ TATA, KAJ?
#
#
# Paraphrased sentences:
# 0: Zakaj misliš, da boš tat, kaj?
# 1: Zakaj pa ti je vseeno, da boš tita, kaj?
# 2: Zakaj pa misliš, da boš tita, kaj?
# 3: Zakaj šepetaj, MALA, SI še vedno v šoku, ko si izvedel, da boš tita, kaj?
# 4: Zakaj pa še vedno govoriš, ti si v šoli, ko si vedel, da boš tita, kaj?
# 5: Zakaj še vedno govoriš, ti pa veš, da boš tita, kaj?
# 6: Zakaj pa misliš, da boš tat, kaj?
# 7: Zakaj pa ne boš šepetal, ko boš izvedel, da boš tita, kaj?
# 8: Zakaj še vedno, zdaj ko ste vedeli, da boš tita, kaj?
# 9: Zakaj pa ti je pomembno, da boš tita, kaj?
#
# -----------------------
#
#
# Original sentence:
# Razumljivo, saj ladjice izpuščajo svoje odplake, tako gospodinjske kot iztrebke, naravnost v vodo.
#
#
# Paraphrased sentences:
# 0: Razumljivo je, da ladji izpuščajo svoje odplake, tako gospodinjske kot iztrebke.
# 1: Razumljivo, saj ladji izpuščajo svoje odplake, tako gospodinjske kot iztrebke, naravnost v vodo.
# 2: Razumljivo, saj ladji izpuščajo svoje odplake, tako gospodinjske kot iztrebke.
# 3: Razumljivo, saj ladji izpuščajo svoje odplake, tako gospodinjske kot tudi iztrebke.
#
# -----------------------
#
#
# Original sentence:
# Tako obdelano mleko je uporabno od 2 do 6 mesecev.
#
#
# Paraphrased sentences:
#
# -----------------------
#
#
# Original sentence:
# To pot je slavilo z 8:1, oba naša hokejista pa sta prispevala po dve točki (po en gol in podajo).
#
#
# Paraphrased sentences:
# 0: To pot je to pot prekinilo z 9: 1, oba naša hokejista pa sta prispevala po dve točki (po en gol in podajo).
# 1: To pot je slavilo z 9: 10, oba naša hokejista pa sta prispevala po dve točki (po en gol in podajo).
# 2: To pot je slavilo z 9: 3, naša naša hokejista pa sta prispevala po dve točki (po en gol in podajo).
# 3: To pot je to pot prekinilo z 9: 10, oba naša hokejista pa sta prispevala po dve točki (po en gol in podajo).
# 4: To pot je slavilo z 9:1, naša hokejista pa sta prispevala po dve točki (po en gol in podajo).
#
# -----------------------
#
#
# Original sentence:
# Ta dokaj optimističen položaj kaže izkoristiti, saj pomeni zelo dobro naložbo za prihodnost.
#
#
# Paraphrased sentences:
# 0: Ta razmeroma optimističen položaj se kaže izkoristiti, saj predstavlja zelo dobro naložbo v prihodnost.
# 1: Izraziti je ta razmeroma optimističen položaj, saj predstavlja zelo dobro naložbo v prihodnost.
# 2: Ta razmeroma optimističen položaj se kaže izkoristiti, saj pomeni zelo dobro naložbo v prihodnost.
# 3: Ta dokaj optimističen položaj se kaže izkoristiti, saj predstavlja zelo dobro naložbo za v prihodnost.
# 4: Ta razmeroma optimističen položaj je izkoristil Ta razmeroma optimističen položaj, saj predstavlja zelo dobro naložbo v prihodnost.
# 5: Izraziti je ta dokaj optimističen položaj, saj predstavlja zelo dobro naložbo za v prihodnost.
# 6: Izraziti je ta dokaj optimističen položaj, saj predstavlja zelo dobro naložbo v prihodnost.
#
# -----------------------
#
#
# Original sentence:
# Osebno se ne čutim odgovornega za zadeve, ki mi jih je pripisal NS.
#
#
# Paraphrased sentences:
# 0: ne počutim se odgovorne za stvari, ki mi jih je pripisal NS.
# 1: ne počutim se odgovorne za stvari, ki mi jih je položil NS.
# 2: ne počutim se odgovorne za zadeve, ki mi jih je položil NS.
# 3: ne počutim se odgovorne za stvari, ki mi jih je naložil NS.
# 4: ne počutim se odgovorne za zadeve, ki mi jih je naložil NS.
#
# -----------------------
#
#
# Original sentence:
# ŠKOFJA LOKA KAMNITNIK, prodamo 1192 m2 zazidljive parcele, ki se nahaja nad OMV-jem v Šk.
#
#
# Paraphrased sentences:
# 0: Škofja Loka kamniti, prodamo 1192 m2 zazidljive parcele, ki se nahaja nad OMV-jem v Šk.
# 1: Škofja Loka kamniti, prodamo 1192 m2 zazidljive zemlje, ki se nahaja nad OMV-jem v Šk.
# 2: Škofja Loka kamnitinska parcela, prodamo 1192 m2 zazidljive parcele, ki se nahaja nad OMV-jem v Šk.
# 3: ŠKOFJA LOKA KAMNITNIK, prodamo 1192 m2 zazidljive parcele, ki leži nad OMV-jem v Šk.
# 4: Škofja Loka KAMNITNIK, prodamo za za okoli 1192 m2 zazidljive parcele, ki se nahaja nad OMV-jem v Šk.
#
# -----------------------
#
#
# Original sentence:
# Že sama delitev ribičev v Pravilniku na športne in rekreacijske se mi zdi neumestna.
#
#
# Paraphrased sentences:
# 0: Delitev ribičev v Pravilniku o ribičih na športne in rekreacijske se mi zdi neumestna.
# 1: Delitev ribičev v Pravilniku o športu in rekreaciji se mi zdi neumestna.
# 2: Delitev ribičev v Pravilniku o razvrstitvi v Pravilniku se mi zdi neumestna.
# 3: Ločevanje ribičev v Pravilniku o ribištvu se mi zdi neumestno.
# 4: Delitev ribičev v Pravilniku o ribištvu se mi zdi neumestna.
# 5: Po mojem mnenju, delitev ribičev v Pravilniku o športu in rekreaciji se mi zdi neumestna.
# 6: Ločevanje ribičev v Pravilniku o ribištvu se mi zdi nepomembno.
# 7: Delitev ribičev v Pravilniku o lovu na športne in rekreacijske se mi zdi neprimerna.
#
# -----------------------
#
#
# Original sentence:
# Izvoznice nafte bodo načrpale samo 24 milijonov sodov na dan
#
#
# Paraphrased sentences:
# 0: Pretopljene nafte bodo samo 24 milijonov sodov na dan.
# 1: Izvoznice nafte bodo samo 24 milijonov sodov na dan
# 2: Izvoznica nafte bo proizvedla le 24 milijonov sodov na dan
# 3: Izvozniki nafte bodo samo 24 milijonov sodov na dan.
# 4: Izvoznice nafte bodo samo 24 milijonov ton na dan.
# 5: Izvoznica nafte je napovedala, da bo načrpala le 24 milijonov sodov na dan
# 6: Izvoznice nafte bodo samo 24 milijonov sodov na dan.
#
# -----------------------
#
#
# Original sentence:
# Šlo je, recimo, za to, ali boš samo pejorativno pisal o reakcionarnem pojavu ali boš v njem videl tudi kaj pozitivnega.
#
#
# Paraphrased sentences:
# 0: Na primer, je šlo za to, ali boš bral lekcijo o reakciji ali boš videl tudi kaj pozitivnega.
# 1: Na primer, je šlo za to, ali boš napisal samo pejorativno o reakcionarnem pojavu ali boš videl tudi kaj pozitivnega v tem.
# 2: Na primer, je šlo za to, ali boš bral samo naj bodocioziteje o reakcionarnem pojavu ali boš videl tudi kaj pozitivnega.
# 3: Recimo, da je šlo za to, ali boš bral samo argumentacijo o reakcionarnem pojavu ali boš videl tudi kaj pozitivnega v tem.
# 4: Recimo, da je šlo za to, ali boš napisal samo pejorativno o reakciji ali boš videl tudi kaj pozitivnega v tem pojavu.
# 5: Na primer, je šlo za to, ali boš pisal samoironite o reakcionarnem pojavu ali boš videl tudi kaj pozitivnega v tem, kar je pozitivnega.
# 6: Na primer, je šlo za to, ali boš napisal samo pejorativno o reakciji ali pa boš videl tudi kaj pozitivnega.
# 7: Na primer, je šlo za to, ali boš pisal samoirotivno o reakciji ali boš videl tudi kaj pozitivnega v tem, kar je pozitivnega.
# 8: Na primer, je šlo za to, ali boš pisal samoirotivno o reakcionarnem pojavu ali boš videl tudi kaj pozitivnega v tem.
# 9: Na primer, je šlo za to, ali boš napisal samo pejorativno o reakciji ali pa boš videl tudi kaj pozitivnega v tem.
#
# -----------------------
#
#
# Original sentence:
# To, da megljenje vizirja izgine s hitrostjo, ni res.
#
#
# Paraphrased sentences:
# 0: to pomeni, da prijemanje pisala izgine s hitrostjo.
# 1: to pomeni, da z meglo izginejo vizir.
# 2: to pomeni, da z megnjenjem izgine vizirja.
# 3: to povzroči, da viziranje ne izgine s hitrostjo.
# 4: to pomeni, da zmanjšanje hitrosti ni res.
# 5: to pomeni, da prilepljanje vizirja izgine s hitrostjo.
# 6: to ni res.
# 7: to ni res, vendar je dejstvo, da z meglo izginejo vizir.
#
# -----------------------
#
#
# Original sentence:
# Saj si oba tudi že končno zaslužita srečo.
#
#
# Paraphrased sentences:
# 0: Oba si tudi končno zaslužita srečo.
#
# -----------------------
#
#
# Original sentence:
# Neporažene ekipe na prvenstvu so le še ZDA, Litva in Turčija.
#
#
# Paraphrased sentences:
# 0: Zmagovalci na prvenstvu so le ZDA, Litva in Turčija.
# 1: Neporažene ekipe na prvenstvu so le ZDA, Litva in Turčija.
# 2: Med poraženimi ekipami so tudi ZDA, Litva in Turčija.
#
# -----------------------
#
#
# Original sentence:
# Srednja vrednost teh dveh ocen je 89 evrov, kar je le šest odstotkov več od včerajšnjega enotnega tečaja delnic Pivovarne Laško.
#
#
# Paraphrased sentences:
# 0: Srednja vrednost teh dveh ocen je 89 evrov, kar je le šest odstotkov več od včerajšnjega enojnega tečaja delnic Pivovarne Laško.
# 1: Srednja cena teh dveh ocen je 89 evrov, kar je le šest odstotkov več kot včerajšnjega enotnega tečaja delnic Pivovarne Laško.
# 2: Srednja cena teh dveh ocen je 89 evrov, kar je le šest odstotkov več od včerajšnjega enojnega tečaja delnic Pivovarne Laško.
# 3: Srednja cena teh dveh ocen je 89 EUR, kar je le šest odstotkov več od včerajšnjega enojnega tečaja delnic Pivovarne Laško.
# 4: Srednja vrednost teh dveh ocen je 89 EUR, kar je le šest odstotkov več od včerajšnjega enotnega tečaja delnic Pivovarne Laško.
# 5: Srednja cena teh dveh ocen je 89 evrov, kar je le šest odstotkov več od včerajšnjega enotnega tečaja delnic Pivovarne Laško.
# 6: Srednja vrednost teh dveh ocen je 89 EUR, kar je le šest odstotkov več od včerajšnjega enojnega tečaja delnic Pivovarne Laško.
#
# -----------------------
#
#
# Original sentence:
# V osnovi gre torej za eksistencialna vprašanja...
#
#
# Paraphrased sentences:
# 0: Izhodišče za to vprašanje so eksistencialna vprašanja...
# 1: Osnovna vprašanja so torej eksistencialna...
# 2: V bistvu gre za eksistencialna vprašanja...
#
# -----------------------
#
#
# Original sentence:
# Svoje šolanje bodo zaključili na Ptuju, v tem majhnem, komornem in zelo specifičnem gledališču.
#
#
# Paraphrased sentences:
# 0: Svoje šolanje bodo končali na Ptuju, v majhnem, komornem in zelo specifičnem gledališču.
# 1: Svoje šolanje bodo zaključili na Ptuju, v majhnem, komornem in zelo specifičnem gledališču.
#
# -----------------------
#
#
# Original sentence:
# Linda skromno pravi: Storila sem tisto, kar bi storila vsaka sestra.
#
#
# Paraphrased sentences:
# 0: Linda skromno pravi: Naredila sem, kar sem storila jaz.
# 1: Linda skromno pravi: Naredila sem, kar sem storila sama.
# 2: Linda skromno pravi: Naredila sem, kar bi lahko storila vsaka ženska.
# 3: Linda skromno pravi: Naredila sem to, kar bi lahko storila vsaka moja sestra.
# 4: Linda skromno pravi: Naredila sem to, kar bi lahko storila vsaka ženska.
# 5: Linda skromno pravi: Naredila sem to, kar bi storila vsaka moja sestra.
#
# -----------------------
#
#
# Original sentence:
# Ker na njem ne bo nič.
#
#
# Paraphrased sentences:
# 0: Ker ne bo ničesar na njem.
# 1: Ker ne bo nobenega od njega.
# 2: Ker ne bo ničesar.
# 3: Ker ne bo nobenega od tam.
#
# -----------------------
#
#
# Original sentence:
# Cene seveda niso navedene, vendar ob zanimanju zanje izveš, da so zelo pretirane za normalnega smrtnika.
#
#
# Paraphrased sentences:
# 0: Seveda pa cene niso določene, toda z zaupanjem si lahko predstavljate, da so pretirane za normalnega smrtnika.
# 1: Seveda pa Cene seveda niso določene, vendar lahko iz izkušenj izveš, da so pretirane za normalnega smrtnika.
# 2: Seveda pa cene niso znane za povprečnega smrtnika, toda z zaupanjem jim je to pretiravanje pretiravanje normalno za normalnega smrtnika.
# 3: Seveda pa cene niso določene, vendar iz izkušenj z njimi izveš, da so pretirane za normalnega smrtnika.
# 4: Seveda pa cene niso znane za normalnega smrtnika, toda iz njih lahko izveš, da so pretirane za normalnega smrtnika.
# 5: Seveda pa cene niso določene, vendar lahko iz izkušenj ugotoviš, da so pretirane za normalnega smrtnika.
# 6: Seveda pa cene niso določene, vendar lahko iz izkušenj izveš, da so pretirane za normalnega smrtnika.
# 7: Seveda pa niso naštete cene, vendar lahko iz izkušenj izveš, da so pretirane za normalnega smrtnika.
# 8: Seveda pa cene niso določene, vendar lahko hitro izvemo, da so pretirane za normalnega smrtnika.
# 9: Seveda pa cene niso določene, vendar ob upoštevanju tega izveš, da so pretirane za normalnega smrtnika.
#
# -----------------------
#
#
# Original sentence:
# V imenu predlagateljev je dopolnilo pojasnjeval poslanec Vili Trofenik.
#
#
# Paraphrased sentences:
# 0: V imenu vložnika je dopolnilo pojasnil poslanec Vili Trofenik.
# 1: V imenu predlagateljev je dopolnilo pojasnil poslanec Vili Trofenik.
# 2: V imenu vložnikov je dopolnilo pojasnil poslanec Vili Trofenik.
# 3: V imenu organizatorjev je dopolnilo pojasnil poslanec Vili Trofenik.
#
# -----------------------
#
#
# Original sentence:
# Finci so brez težav ugnali Latvijo.
#
#
# Paraphrased sentences:
# 0: Finci so v celoti premagali Latvijo.
# 1: Finci so v Latvijo zlahka premagali Latvijo.
# 2: finci so zlahka ugnali Latvijo.
# 3: Finci so zlahka ugnali Latvijo.
# 4: Finci so lahko premagali Latvijo brez težav.
# 5: finski uporniki so v ponedeljek brez težav premagali Latvijo.
#
# -----------------------
#
#
# Original sentence:
# Za kaj več v Evropi ne le, da primanjkuje moči, ampak tudi prave volje ni.
#
#
# Paraphrased sentences:
# 0: Moči v Evropi ne primanjkuje, ampak tudi ni prave volje.
# 1: Moči v Evropi ne primanjkuje, ampak tudi ni prave volje za kaj več.
# 2: Moči v Evropi ne primanjkuje, vendar tudi prave volje ni.
# 3: Ne le, da v Evropi ni moči, ampak tudi ni prave volje.
# 4: Moči v Evropi ne primanjkuje, vendar pa tudi prave volje ni.
# 5: Ne le, da je v Evropi primanjkuje moči, ampak ni prave volje.
# 6: Ne samo, da v Evropi ne primanjkuje moči, ampak tudi ni prave volje.
#
# -----------------------
#
#
# Original sentence:
# Je to razumevajoč nasmešek najboljše prijateljice?
#
#
# Paraphrased sentences:
# 0: Je to vaš smeh nasmešek najboljši prijatelj?
# 1: Je to njen nasmešek najboljši prijatelj?
# 2: Je to najboljši nasmeh najboljši prijatelj?
# 3: Je to njen nasmeh najboljši prijatelj?
# 4: Je to smeh resnejši nasmeh vaše najboljše prijateljice?
# 5: Je to smeh resnejši od njenega nasmeha?
# 6: Je to vaš nasmeh nasmešek najboljše prijateljice?
# 7: Je to vaš najboljši nasmeh?
#
# -----------------------
#
#
# Original sentence:
# Komisija je dobila tudi zahtevo, naj prepove uporabo električnih harpun, ki jih japonski kitolovci uporabljajo pri sekundarnem ubijanju kitov.
#
#
# Paraphrased sentences:
# 0: Komisija je dobila tudi zahtevo, naj se prepove uporaba električnih harpun, ki jih japonski kitolovci uporabljajo pri sekundarnem ubijanju kitov.
# 1: Komisija je tudi dobila zahtevo, naj neha uporabljati električne harpune, ki jih japonski kitolovci uporabljajo pri sekundarnem ubijanju kitov.
# 2: Odbor je tudi dobil zahtevo, naj neha uporabljati električne harpune, ki jih japonski kitolovci uporabljajo pri sekundarnem uničevanju kitov.
# 3: Komisija je dobila tudi zahtevo, naj neha uporabljati električne harpune, ki jih japonski kitolovci uporabljajo pri sekundarnem ubijanju kitov.
# 4: Odbor je tudi dobil zahtevo, naj neha uporabljati električne harpune, ki jih japonski kitolovci uporabljajo pri sekundarnem ubijanju kitov.
# 5: Komisija je tudi dobila zahtevo, naj neha uporabljati električne harpune, ki jih japonski kitolovci uporabljajo pri sekundarnem umiku kitov.
#
# -----------------------
#
#
# Original sentence:
# Turistično društvo Naklo je v petek povabilo v dom Janeza Filipiča dobitnike letošnjih priznanj za lepo urejene domove.
#
#
# Paraphrased sentences:
# 0: Turistično društvo Naklo je v petek zvečer povabilo k domu Janeza Filipiča, da obišče domove za lepo urejene domove.
# 1: Turistično društvo Naklo je v petek povabilo k domu Janeza Filipiča, da obišče domove za lepo urejena naselja.
# 2: Turistično društvo Naklo je v petek zvečer povabilo k domu Janeza Filipiča na ogled dobitniki letošnjih priznanj za lepo urejene domove.
# 3: Turistično društvo Naklo je v petek zvečer povabilo k domu Janeza Filipiča za lepo urejena naselja.
# 4: V petek je Turistično društvo Naklo v dom Janeza Filipiča povabilo najboljše domove za lepo urejena naselja.
# 5: V petek je Turistično društvo Naklo objavilo zlato sredino za lepo urejena stanovanja v domu Janeza Filipiča.
# 6: Turistično društvo Naklo je v petek zvečer povabilo k domu Janeza Filipiča kot prvoglasno urejeno naselje.
# 7: Turistično društvo Naklo je v petek zvečer povabilo k domu Janeza Filipiča med dobitniki letošnjih priznanj za lepo urejene domove.
# 8: Turistično društvo Naklo je v petek zvečer povabilo k domu Janeza Filipiča za lepo urejena stanovanja.
#
# -----------------------
#
#
# Original sentence:
# Hkrati naj občina takoj začne s postopki za morebitno gradnjo novega vrtca.
#
#
# Paraphrased sentences:
# 0: Hkrati je treba takoj začeti postopke za začetek gradnje novega vrtca.
# 1: Hkrati pa občina takoj začne s postopki za morebitno gradnjo novega vrtca.
# 2: Hkrati je treba takoj začeti s postopki za morebitno gradnjo novega vrtca.
# 3: Hkrati je treba takoj začeti postopke za morebitno gradnjo novega vrtca.
# 4: Hkrati pa bi rad takoj začel postopke za morebitno gradnjo novega vrtca.
#
# -----------------------
#
#
# Original sentence:
# Finec zmagovalec tudi v teku na 50 km klasično - Srebro senzacionalnemu Estoncu Veerpaluju - Botvinov pritekel Avstriji bron
#
#
# Paraphrased sentences:
# 0: Finec zmagovalec tudi v teku na 50 km klasično - Srebro ugledni Estonec Veerpalu - Botvin osvojil bron
# 1: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - bron
# 2: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - Prelom je prineslo Avstriji bron
# 3: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - Dobližje senzacionalnemu Estoncu Veerpaluju -
# 4: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - Bencin osvojil Avstrijo bron
# 5: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - Botvin je osvojil bron
# 6: Finec zmagovalec tudi v teku na 50 km klasično - Srebro suverene Estonec Veerpalu - brona je priigral Avstrijo bron
# 7: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - brona je prinesel v Avstrijo bron
# 8: Finec zmagovalec tudi v teku na 50 km klasično - Srebro suverene Estonce Veerpaluja - Botvinov prejel bron
# 9: Finec zmagovalec tudi v teku na 50 km klasično - Srebro avstrijskemu državljanu Veerpaluju - brona je dal Botvin
#
# -----------------------
#
#
# Original sentence:
# Leta so bežala in z njim tudi moja mladost.
#
#
# Paraphrased sentences:
# 0: Leta so bežala in z njim moja mladost.
# 1: Miša je leta bežala in z njim moja mladost.
# 2: Leta so bežala in z mano se je mladost končala.
# 3: V teh letih so minila leta in z njim moja mladost.
# 4: Toda leta so bežala in z mano je bila mladost.
# 5: V tistih letih so leta bežala in z mano je živela moja mladost.
#
# -----------------------
#
#
# Original sentence:
# Upokojenci so se izkazali tudi v igranju taroka.
#
#
# Paraphrased sentences:
# 0: Upokojenci so se izkazali tudi v taroku.
# 1: Upokojenci so se tudi odlikovali v taroka.
# 2: Upokojenci so se odlikovali tudi v taroku.
# 3: Upokojenci so se tudi odlikovali v taroku.
#
# -----------------------
#
#
# Original sentence:
# Nebo Nebo nam podarilo je dež, padavine letijo po zraku. ...
#
#
# Paraphrased sentences:
# 0: Nebo nam je podarilo vodo, da bi videli, kaj se dogaja...
# 1: Nebo nam je podarilo dež, padavine letijo v zraku....
# 2: Nebo nam je podarilo vodo, da bi se na zemlji namakal dež.
# 3: Nebo nam je darilo vodo, ki leti v zraku.
# 4: Nebo nam je podarilo dež, padavine letijo v zraku.
# 5: Nebo nam je podarilo vodo, ki leti v zraku.
# 6: Nebo nam je podarilo vodo, da bi se na zemlji namočili.
# 7: Nebo nam je darilo vodo, padavine letijo v zraku.
# 8: Nebo nam je dala vodo, padavine letijo v zraku....
# 9: Nebo nam je podarilo vodo, da bi serila z nami.
#
# -----------------------
#
#
# Original sentence:
# Stražarji so me dvignili s tal in me stlačili v avto.
#
#
# Paraphrased sentences:
# 0: Stražarji so me dvignili s tal in me strpali v avto.
# 1: Stražarji so me dvignili s tal in me strmeč v avto.
# 2: Stražarji so me dvignili s tal in me strpali v svoj avto.
# 3: Stražarji so me zgrabili s tal in me potisnili v avto.
#
# -----------------------
#
#
# Original sentence:
# Dietrich - Naglič, Ladje - morja - pristanišča, Ljubljana, 1967.
#
#
# Paraphrased sentences:
# 0: Dietrich - Naglič, Ladje - morja - luke, Ljubljana, 1967.
#
# -----------------------
#
#
# Original sentence:
# Navdušeni smo nad sodelovanjem s Patrickom Dempseyjem.
#
#
# Paraphrased sentences:
#
# -----------------------
#
#
# Original sentence:
# Za svetovno prvenstvo na Japonskem smo imeli visoka pričakovanja, ker je lansko evropsko prvenstvo napovedalo lepše čase za slovensko reprezentančno košarko.
#
#
# Paraphrased sentences:
# 0: Za svetovno prvenstvo na Japonskem smo imeli visoka pričakovanja, ker je lansko evropsko prvenstvo napovedala boljše čase za slovensko športno košarko.
# 1: Za svetovno prvenstvo v Tokiu smo imeli visoka pričakovanja, ker je lansko evropsko prvenstvo napovedala boljše čase za slovensko športno košarko.
# 2: Za svetovno prvenstvo na Japonskem smo imeli visoka pričakovanja, ker je lansko evropsko prvenstvo napovedala boljše čase za slovensko reprezentančno košarko.
# 3: Za svetovno prvenstvo na Japonskem smo imeli visoka pričakovanja, ker je lansko evropsko prvenstvo napovedala boljše čase za slovenski reprezentanci.
# 4: Za svetovno prvenstvo v Tokiu smo imeli visoka pričakovanja, ker je lansko evropsko prvenstvo napovedala boljše čase za slovenski reprezentanci.
#
# -----------------------
#
#
# Original sentence:
# Na sodišču se izkaže, da je Sam sam sebi najslabša obramba.
#
#
# Paraphrased sentences:
# 0: Na sodišču se izkaže, da je To za Sama najboljša obramba.
# 1: Na sodišču se izkaže, da je To Susan najboljša obramba.
# 2: Na sodišču se izkaže, da je sam sebi najboljša obramba.
# 3: Na sodišču se izkaže, da je Tomov edini način obrambe.
#
# -----------------------
#
#
# Original sentence:
# Uprava v Gorici bo zaprta od 15. do 19. avgusta.
#
#
# Paraphrased sentences:
# 0: Upravni odbor v Gorici bo zaprt od 15. do 19. avgusta.
# 1: Urad v Gorici bo zaprt od 15. do 19. avgusta.
#
# -----------------------
#
#
# Original sentence:
# Italija - Bergamo, Gran Fondo Internazionale Felice Gimondi
#
#
# Paraphrased sentences:
# 0: Italija - Bergamo, Gran Fondo Internationale Felice Gimondi
#
# -----------------------
#
#
# Original sentence:
# Sedemmetrovke: Cimos Koper 6 (4), Gorenje 5 (4).
#
#
# Paraphrased sentences:
# 0: Lestvice Cimos Koper 6 (4), Gorenje 5 (4).
# 1: : Sedemmetrovke Cimos Koper 6 (4), Gorenje 5 (4).
# 2: Lestvice: Cimos Koper 6 (4), Gorenje 5 (4).
# 3: : Štajerka Cimos Koper 6 (4), Gorenje 5 (4).
#
# -----------------------
#
#
# Original sentence:
# Laura se mu je predajala, ne da bi se zavedala, kaj sploh počne.
#
#
# Paraphrased sentences:
# 0: Laura se mu je predajala, ne da bi se zavedala, kaj počne.
#
# -----------------------
#
#
# Original sentence:
# Korektor naj bo za kak ton svetlejši od tona kože; nikoli ne kupite pretemnega.
#
#
# Paraphrased sentences:
# 0: rektor mora biti za nekaj ton širši od tone kože; nikoli ne kupite presvetlega.
# 1: Certifikator mora biti za nekaj ton širši od tone kože; nikoli ne kupite presvetlega.
# 2: Konrektor mora biti za nekaj ton širši od tone kože; nikoli ne kupite presvetlega.
# 3: rektor mora biti za nekaj ton širši od tone kože; nikoli ne kupite presvetlega tona.
# 4: rektor mora biti za kak ton širši od tone kože; nikoli ne kupite presvetlega.
# 5: Konrektor mora biti za nekaj ton širši od tone kože; nikoli ne kupite presvetlega tona.
# 6: Končna enota mora biti za približno en ton temnejša od tona kože; nikoli ne kupite presvetlega.
#
# -----------------------
#
#
# Original sentence:
# Staro stanovanje v centru mesta lahko spremenimo v romantično graščino, pusto hišo v prijeten domek.
#
#
# Paraphrased sentences:
# 0: Staro stanovanje v središču mesta je lahko v romantični graščini, majhnem domek.
# 1: Staro stanovanje v središču mesta je lahko spremeniti v romantično vas, v lepo hišo, prijeten domek.
# 2: Staro stanovanje v središču mesta lahko spremenimo v romantično vas, v lepo graščino, pusta hiša v prijetnem zaodrju.
# 3: Staro stanovanje v središču mesta lahko spremenimo v romantično vas, v lepo hišo, pusta hiša v prijetnem zatoku.
# 4: Staro stanovanje v središču mesta lahko spremenimo v romantično vas, v lepo hišo, prijeten domek.
# 5: Staro stanovanje v središču mesta je lahko tudi romantično, grajsko dvorišče, lepo hišo v prijetnem senci.
# 6: Staro stanovanje v središču mesta je lahko v romantični graščini, majhnem vrtu v prijetnejših dneh.
# 7: Staro stanovanje v središču mesta je lahko tudi romantično, grajsko dvorišče, pusta hiša v lepem razpoloženju.
# 8: Staro stanovanje v središču mesta lahko spremenimo v romantično graščino, pusto hišo spremeni v prijeten domek.
#
# -----------------------
#
#
# Original sentence:
# Torej, ne gre za avtosugestijio, pač pa za heterosugestijio.
#
#
# Paraphrased sentences:
# 0: Torej, ne gre za avtosugestijo, ampak za heterosugestijo.
# 1: Torej, ne gre za avtosugestijio, ampak za heterosugestijo.
# 2: Torej, ne gre za avtosugestijo, ampak za heterosugestijio.
# 3: Torej, ne gre za avtosugestijo, pač pa za heterosugesti.
# 4: Torej ne gre za avtosugestijo, pač pa za heterosugestijo.
#
# -----------------------
#
#
# Original sentence:
# Od izbruha vojne na Hrvaškem in v Bosni in Hercegovini so evropske države najprej priskrbele beguncem začasno zatočišče.
#
#
# Paraphrased sentences:
# 0: Od izbruha vojne na Hrvaškem in v Bosni in Hercegovini so evropske države najprej ponudile začasno zatočišče evropskim državljanom.
# 1: Od izbruha vojne na Hrvaškem in v Bosni in Hercegovini so evropske države najprej priskrbele začasno zatočišče za begunce.
#
# -----------------------
#
#
# Original sentence:
# Nič nismo slišali recimo o tem, ali se delovni absentizem v javnem sektorju povečuje ali zmanjšuje.
#
#
# Paraphrased sentences:
# 0: Na primer, nismo slišali nič o tem, ali se delovni izostaja od njih povečuje ali se zmanjšuje.
# 1: Nobenega nismo slišali o tem, ali se delovni izostaja iz javnih služb ali ne.
# 2: Nobenega dokaza ali raziskave ni bilo, da se delovni izobesa med javnim in zasebnim sektorjem povečuje ali zmanjšuje.
# 3: Nobenih pogovorov nismo vedeli, da se delovni izobesa med javnim in zasebnim sektorjem dela povečuje ali pa se zmanjšuje.
# 4: Nobenega govora ni bilo o tem, ali se je delovni izostajal ali se bo povečal.
# 5: Na primer, nismo slišali nič o tem, ali se delovni izostaja delovni preobremenjenosti javni ali zasebni sektor povečuje ali se zmanjšuje.
# 6: Nobenega članka o tem, ali se delovni izostaja iz javnega sektorja ali se zmanjšuje.
# 7: Nobenega ni bilo slišanega, da bi povečali ali zmanjšali delovni izobeg.
# 8: Nobenega dokaza ali raziskave nismo vedeli, da se delovni izostaja ali zmanjšuje.
#
# -----------------------
#
#
# Original sentence:
# To velja tako za medicino kot za novinarstvo, odvetnike in bankirje, inženirje in zobozdravnike.
#
#
# Paraphrased sentences:
# 0: To velja tako za medicino, odvetništvo, odvetništvo in bančništvo, inženirji in zobozdravniki.
# 1: To velja tako za medicino, odvetništvo, odvetništvo in bankirji, inženirji in zobozdravniki.
# 2: To velja tako za medicino, odvetništvo, odvetništvo in inženirji in zobozdravstveni pregledi.
# 3: To velja tako za medicino, odvetništvo, odvetništvo in odvetniki, inženirji in zobozdravniki.
# 4: To velja tako za medicino, odvetništvo, odvetništvo in bančni inženirji in zobozdravniki.
# 5: To velja tako za medicino, odvetništvo, odvetništvo in bančništvo, in zdravniki in zobozdravniki.
#
# -----------------------
#
#
# Original sentence:
# V moški četverki v zadnji predaji Tyson Gay ni dobil palice oziroma mu je padla iz rok.
#
#
# Paraphrased sentences:
# 0: V ženski četverki v zadnji predaji Tysona Gayja ni dobil niti ene palice oziroma mu je padla iz rok.
# 1: V ženski četverki, ki je v zadnji predaji padla iz rok, Tyson Gay ni dobil šale ali padla iz rok.
# 2: V ženski četverki, ki jo je vodil Tyson Gay, ta ni dobil šasije ali mu je padla iz rok.
# 3: V ženski četverki v zadnji predaji Tyson Gay ni dobil šalabija ali mu je padla iz rok.
# 4: V ženski četverki, ki je v zadnji predaji padla iz rok, Tyson Gay ni dobil šalabeta ali mu je padla iz rok.
# 5: V ženski četverki, ki je v zadnji predaji padla na tla, Tyson Gay ni dobil šalabeta ali mu je padla iz rok.
# 6: V ženski četverki, ki je v zadnji predaji padla na njegovo mesto, je bil Tyson Gay izgubil palico ali mu je padla iz rok.
# 7: V ženski četverki, ki je v zadnji predaji padla na tla, Tyson Gay ni dobil šalabije ali pa je padla iz njegovega urnika.
#
# -----------------------
#
#
# Original sentence:
# Na letošnjem 13. svetovnem prvenstvu bo nastopilo prek 8.000 veteranov in veterank iz več kot 120 držav sveta.
#
#
# Paraphrased sentences:
# 0: Na letošnjem 13. svetovnem prvenstvu bo nastopilo prek 8.000 veteranov in veterank iz več kot 120 držav.
# 1: Na letošnjem 13. svetovnem prvenstvu bo nastopilo več kot 8.000 veteranov in veterank iz več kot 120 držav.
# 2: Na letošnjem 13. svetovnem prvenstvu bo sodelovalo več kot 8.000 veteranov in veterank iz več kot 120 držav.
#
# -----------------------
#
#
# Original sentence:
# Ob takšnem pristopu in pripravljenosti lahko igra še 10 let.
#
#
# Paraphrased sentences:
# 0: Takšnega pristopa in pripravljenosti lahko igra še 10 let.
# 1: Takšnega pristopa in pripravljenosti lahko igrate še 10 let.
# 2: Takšnih pristopov in pripravljenosti lahko igrate še 10 let.
# 3: Takšno obnašanje in pripravljenost lahko traja še 10 let.
# 4: Takšnih pristopov in pripravljenosti lahko igra še 10 let.
#
# -----------------------
#
#
# Original sentence:
# Za preživetje umetnosti je potrebno pravilno ravnovesje obeh polov.
#
#
# Paraphrased sentences:
# 0: Za preživetje umetnosti je potrebno pravilno ravnovesje med obema poloma.
#
# -----------------------
#
#
# Original sentence:
# To sem občutil že na lastni koži.
#
#
# Paraphrased sentences:
# 0: to sem občutil na lastni koži.
# 1: to sem čutil na lastni koži.
#
# -----------------------
#
#
# Original sentence:
# Mesto, ki ga krasijo imenitni spomeniki preteklosti, ni več umazano, drzno se postavlja ob bok tudi modnim središčem na starem kontinentu
#
#
# Paraphrased sentences:
# 0: Mesto, ki ga krasijo ugledni spomeniki preteklosti, ni več umazano in drzno se postavlja ob bok tudi modnim središčem na starem kontinentu.
# 1: Mesto, ki ga krasijo impresivni spomeniki preteklosti, ni več umazano in drzno se postavlja ob bok tudi modnim središčem na starem kontinentu.
# 2: Mesto, ki ga krasijo impresivni spomeniki preteklosti, ni več umazano in drzno se postavlja ob bok tudi modnim središčem na stari celini
#
# -----------------------
#
#
# Original sentence:
# V tovarni na Hrvaškem bo sprva dobilo delo 250 ljudi, ob koncu leta 2002 pa naj bi jih bilo zaposlenih 400.
#
#
# Paraphrased sentences:
# 0: Sprva bo v tovarni na Hrvaškem zaposlenih 250 ljudi, ob koncu leta 2002 pa bo to število zaposlenih 400.
# 1: Sprva bo v tovarni na Hrvaškem najprej začelo delati 250 ljudi, ob koncu leta 2002 pa bo ta številka znašala 400.
# 2: Sprva bo v tovarni na Hrvaškem najprej zaposlitev dobilo 250 ljudi, ob koncu leta 2002 pa bo to pomenilo 250 ljudi.
# 3: Sprva bo v tovarni na Hrvaškem na voljo 250 ljudi, ob koncu leta 2002 pa bo ta številka znašala 400.
# 4: Sprva bo v tovarni na Hrvaškem zaposlenih 250 ljudi, ob koncu leta 2002 pa naj bi jih bilo 400.
# 5: Sprva bo v tovarni na Hrvaškem najprej ustvarilo 250 ljudi, ob koncu leta 2002 pa bo ta številka naraščala.
# 6: Sprva bo v tovarni na Hrvaškem najprej ustvarilo 250 ljudi, ob koncu leta 2002 pa bo ta številka znašala 400.
# 7: Sprva bo v tovarni na Hrvaškem najprej zaposlilo 250 ljudi, ob koncu leta 2002 pa bo to število zaposlenih 400.
# 8: Sprva bo v tovarni na Hrvaškem ustvarilo 250 ljudi, v Zagrebu pa bo delalo 400 ljudi.
# 9: Sprva bo v tovarni na Hrvaškem najprej delalo 250 ljudi, ob koncu leta 2002 pa bo to pomenilo 400.
#
# -----------------------
#
#
# Original sentence:
# Menim, da smo navajeni, da vidimo podobne stvari skupaj.
#
#
# Paraphrased sentences:
# 0: mislim, da smo navajeni gledati na podobne stvari skupaj.
# 1: mislim, da smo navajeni gledati na podobne stvari.
#
# -----------------------
#
#
# Original sentence:
# Ravno obratno ima Rudar tudi v pokalu visoke ambicije.
#
#
# Paraphrased sentences:
# 0: Ravno nasprotno, Rudar ima tudi visoke ambicije v pokalu.
# 1: Ravno nasprotno, Rudar ima tako visoke ambicije v pokalu.
#
# -----------------------
#
#
# Original sentence:
# Želim si spoznati čim več novih prijateljev in ob tem ohraniti tudi stare.
#
#
# Paraphrased sentences:
# 0: želim si več novih prijateljev in ob njih ohraniti tudi stare.
# 1: želim si več novih prijateljev in ob tem ohraniti tudi stare.
# 2: rad bi spoznal čim več novih prijateljev in ohranil tudi stare.
# 3: želim si dobiti čim več novih prijateljev in jih ohraniti tudi za stare.
# 4: želim si pridobiti čim več novih prijateljev in ob njih ohraniti tudi stare.
#
# -----------------------
#
#
# Original sentence:
# Sploh pa ni jasno, zakaj male države sploh kupujejo orožje, razen za krotitev lastnega naroda.
#
#
# Paraphrased sentences:
# 0: Neb jasno je, zakaj velike države uporabljajo orožje, razen za discipliniranje lastnega naroda.
# 1: Ne zdi se jasno, zakaj male države uporabljajo orožje, razen za discipliniranje lastnega naroda.
# 2: Jasno pa ni jasno, zakaj male države uporabljajo orožje, razen za discipliniranje lastnega naroda.
# 3: Vendar ni jasno, zakaj male države sploh kupujejo orožje, razen za zakrivanje lastnega naroda.
# 4: Neb jasno je, zakaj majhne države uporabljajo orožje, razen za discipliniranje lastnega naroda.
# 5: Ne pove nam, zakaj male države sploh kupujejo orožje, razen za strmoglavljenje lastnega naroda.
# 6: Neb jasno je, zakaj male države kupujejo orožje, razen za discipliniranje lastnega naroda.
# 7: Vendar pa ni jasno, zakaj male države sploh kupujejo orožje, razen za discipliniranje lastnega naroda.
# 8: In sploh ni jasno, zakaj male države kupujejo orožje, razen za discipliniranje lastnega naroda.
# 9: Neb jasno je, zakaj male države uporabljajo orožje, razen za discipliniranje lastnega naroda.
#
# -----------------------
#
#
# Original sentence:
# Primož Peterka je blestel v najstniških letih, potem pa ni nikoli več našel vrhunstva.
#
#
# Paraphrased sentences:
# 0: Primož Peterka je blestel v najstniških letih, vendar ni našel vrhunca.
#
# -----------------------
#
#
# Original sentence:
# Vendar pa podrobnejša analiza energetske panoge kaže na dokaj kompleksne razmere, ki narekujejo primerno strategijo energetskih družb.
#
#
# Paraphrased sentences:
# 0: Vendar pa podrobnejša analiza energetskega sektorja kaže na precej zapletene razmere, ki narekujejo primerno strategijo energetskih družb.
# 1: Vendar pa podrobnejša analiza energetskega sektorja kaže na zelo zapletene razmere, ki narekujejo primerno strategijo energetskih družb.
# 2: Vendar pa podrobnejša analiza energetskih dejavnosti kaže na zelo zapletene razmere, ki narekujejo primerno strategijo energetskih družb.
#
# -----------------------
#
#
# Original sentence:
# Zdaj je revše, tajkunček, ki je preganjal tajkune.
#
#
# Paraphrased sentences:
# 0: Zdaj je revščina, tajkunček, ki preganja tajkune.
# 1: Zdaj je revščina, tajkunček, ki je preganjal tajkune.
# 2: zdaj je revščina, tajkunček, ki je preganjal tajkune.
#
# -----------------------
#
#
# Original sentence:
# SOBO s souporabo kuhinje in kopalnice oddam urejeni osebi.
#
#
# Paraphrased sentences:
# 0: dajem v najem kuhinjo in kopalnico ločeno za urejen osebe.
# 1: v kuhinjo s kuhinjo in kopalnico dajem osebi, ki uporablja kuhinjo in kopalnico.
# 2: dajem v najem kuhinjo in kopalnico tudi redkim.
# 3: dajem v najem kuhinjo in kopalnico ločeno za urejeno osebo.
# 4: dajem v najem sobe s kuhinjo in kopalnico.
# 5: dajem v najem kuhinjo in kopalnico za urejeno osebo.
#
# -----------------------
#
#
# Original sentence:
# Zanimivosti iz moje šolske torbe DA
#
#
# Paraphrased sentences:
# 0: Zanimivobe iz moje šolske torbe
# 1: Zanimivobe iz mojega šolskega nahrbtnika
#
# -----------------------
#
#
# Original sentence:
# Jaz bi rekel, da temu zakonu lahko rečemo Zakon o prostorskem projektiranju, po urbanističnem projektiranju.
#
#
# Paraphrased sentences:
# 0: rekel bi, da temu zakonu lahko rečemo Zakon o prostorskem načrtovanju, projektiranju, itd.
# 1: rekel bi, da temu zakonu lahko rečemo tudi Zakon o prostorskem načrtovanju, projektiranje, itd.
# 2: rekel bi, da temu zakonu lahko rečemo Zakon o prostorskem načrtovanju, projektiranje, itd.
# 3: rekel bi, da temu zakonu lahko rečemo Zakon o prostorskem načrtovanju, po urbanističnem projektiranju.
# 4: rekel bi, da temu zakonu lahko rečemo tudi Zakon o prostorskem načrtovanju, projektiranju, itd.
#
# -----------------------
#
#
# Original sentence:
# Tako imajo reke po daljših padavinah res barvo kave z mlekom in odbijajoč videz.
#
#
# Paraphrased sentences:
# 0: Tako, po dolgih padavinah, reke dajejo res barvo kave z mlekom in odbijajoč videz.
# 1: Tako, po dolgih padavinah, imajo reke res barvo kave z mlekom in odbijajoč videz.
# 2: Reke tako dobijo barvo kave z mlekom in odbijajoč videz.
# 3: Tako, po kratkih nalivih, reke spremenijo barvo kave z mlekom in odbijajoč videz.
# 4: Tako, po kratkih padavinah, reke dajejo kabino z mlekom in odbijajoč videz.
# 5: Reke tako rade kave zamenjajo mleko in odbijajoč videz.
# 6: Tako, po kratkih padavinah, reke dajejo barvi kave z mlekom in odbijajoč videz.
# 7: Reke tako res dajejo barvo kave z mlekom in odbijajoč videz.
#
# -----------------------
#
#
# Original sentence:
# Zaradi hudih poškodb se zdravi v brežiški bolnišnici.
#
#
# Paraphrased sentences:
# 0: Za hude poškodbe se zdravi v brežiški bolnišnici.
#
# -----------------------
#
#
# Original sentence:
# Videoigre vedno privlačijo dvakrat žgano rođevino in teh je v Prekmurju kar precej.
#
#
# Paraphrased sentences:
# 0: Video igre vedno privlačijo dva žgana rođevina in teh je v Prekmurju kar nekaj.
# 1: Videoigre vedno privlačijo dva žgana rođevina in teh je v Prekmurju kar nekaj.
# 2: Video igre vedno privlačijo dva žgana rodbina in teh je v Prekmurju kar nekaj.
#
# -----------------------
#
#
# Original sentence:
# Ta proces socialnega dogovarjanja je bil dolg.
#
#
# Paraphrased sentences:
#
# -----------------------
#
#
# Original sentence:
# Pred leti je SSG premoglo tudi gledališko in baletno šolo.
#
#
# Paraphrased sentences:
# 0: Pred leti je SSG premogel tudi gledališko in baletno šolo.
# 1: Pred leti je SSG premogli tudi gledališko in baletno šolo.
#
# -----------------------
#
#
# Original sentence:
# Mene pa zanima, kako se odpre nov blog.
#
#
# Paraphrased sentences:
# 0: Toda zanima me, kako se odpre nov blog.
# 1: Zanima me, kako se lahko odpre nov članek.
# 2: Toda zanima me, kako se odpre nov članek.
#
# -----------------------
#
#
# Original sentence:
# Tel.: (040) 828 855, (040) 747 874
#
#
# Paraphrased sentences:
#
# -----------------------
#
#
# Original sentence:
# V EU ga morajo opravljati poklicni vozniki, vozniki začetniki itd.
#
#
# Paraphrased sentences:
# 0: V EU ga morajo opravljati poklicni vozniki, vozniki vozniki začetniki itd.
#
# -----------------------
#
#
# Original sentence:
# Očitno je bilo, da v nobenem primeru niso pripravljeni nadaljevati sodelovanja z mozirsko Komunalo.
#
#
# Paraphrased sentences:
# 0: Bilo je očitno, da v nobenem primeru ne bi pripravljeni nadaljevati sodelovanja z mozirsko Komunalo.
# 1: Bilo je očitno, da v nobenem primeru niso pripravljeni nadaljevati sodelovanja z mozirsko Komunalo.
# 2: Bilo je očitno, da v nobenem primeru niso pripravljeni nadaljevati sodelovanja z moravsko Komunalo.
#
# -----------------------
#
#
# Original sentence:
# Bomo torej kdaj iznašli zdravilo, ki bo epilepsijo preprečilo?
#
#
# Paraphrased sentences:
# 0: Ali bomo kdaj poskusili zdravilo, ki bo preprečilo epilepsijo?
# 1: Ali bomo kdaj našli zdravilo, ki bo preprečilo epilepsijo?
# 2: Ali smo se naučili zdravila, ki bo preprečila epilepsijo?
# 3: Ali bomo kdaj odkrili zdravilo, ki bo preprečilo epilepsijo?
# 4: Ali bomo kdaj odkrili zdravilo, ki bo preprečilo paralizo?
#
# -----------------------
#
#
# Original sentence:
# Zadnja leta je bila ena mojih boljših vlog lik dedka v Gospe poslančevi.
#
#
# Paraphrased sentences:
# 0: V zadnjih letih je bila ena mojih boljših vlog lik očeta v Gospe poslančeve.
# 1: V zadnjih letih je bila ena mojih boljših vlog lik očeta v Gospe poslancu.
# 2: V zadnjih letih je bila ena mojih boljših vlog lik očeta v Gospe.
#
# -----------------------
#
#
# Original sentence:
# S tem je amandma k naslovu seveda postal brezpredmeten.
#
#
# Paraphrased sentences:
# 0: Tako je bil amandma k naslovu seveda brezpredmeten.
# 1: S tem je bil amandma k naslovu povsem brezpredmeten.
# 2: S tem je bil članek za naslovnika povsem nepomemben.
# 3: S tem je bil članek o naslovu takoj brezpredmeten.
# 4: S tem je bil članek za naslovnika povsem nerodljiv.
# 5: S tem je bil predlog članka povsem nepotreben.
# 6: S tem je bil predlog za razširitev članka povsem nesmiseln.
#
# -----------------------
#
#
# Original sentence:
# Vse, kar bo temu sledilo, pa bo omejeno.
#
#
# Paraphrased sentences:
# 0: Vse, kar bo okoli vas, omejeno.
# 1: Vse, kar bo sledilo, bo omejeno.
#
# -----------------------
#
#
# Original sentence:
# Rak prostate navadno napreduje zelo počasi in ne povzroča težav, dokler ni že napredoval.
#
#
# Paraphrased sentences:
# 0: Rak prostate običajno napreduje zelo počasi in ne povzroča težav, dokler ni že napredoval.
# 1: Rak prostate ponavadi napreduje zelo počasi in ne povzroča težav, dokler ni napredoval.
# 2: Rak prostate običajno napreduje zelo počasi in ne povzroča težav, dokler rak še ni napredoval.
# 3: Rak prostate ponavadi poteka zelo počasi in ni težav, dokler ni že napredoval.
# 4: Rak prostate ponavadi napreduje zelo počasi in ne povzroča težav, dokler ni že napredoval.
# 5: Rak prostate ponavadi poteka zelo počasi in ni težav, dokler ni napredoval.
#
# -----------------------
#
#
# Original sentence:
# Obdobje žalosti tudi ni dolgo, razen če se prelevi v depresijo.
#
#
# Paraphrased sentences:
# 0: Obdobje žalosti prav tako ni dolgo, razen če se prelevi v depresijo.
# 1: Obdobje žalosti ni dolgo, razen če se prelevi v depresijo.
#
# -----------------------
#
#
# Original sentence:
# Bolan na duši in telesu se sodobni človek utaplja v vulgarnosti, nasilju, nemorali, pobijanju, goljufijah ...
#
#
# Paraphrased sentences:
# 0: Današnji človek se bojuje proti vulgarnosti, nasilju, nemoralnosti, pobijanju, prevare...
# 1: Današnji človek se bojuje v vulgarnosti, nasilju, nemoralnosti, pobijanju, prevari...
# 2: Današnji človek se v vulgarnosti, nasilju, nasilju, kriminalu, kriminalu...
# 3: Današnji človek se v vulgarnosti, nasilju, nemoralnem, ubijanju, kriminalih...
# 4: sodobnega človeka se v izbruhih, nasilju, nasilju, kriminalu, kriminalu...
# 5: sodobnega človeka se utaplja v vulgarnosti, nasilju, nemoralnosti, pobijanju, prevar...
# 6: Današnji človek se bojuje v vulgarnosti, nasilju, nemoralnosti, pobijanju, prevar...
# 7: Današnji človek se bo v izbruhih vulgarnosti, nasilju, klavrni igri, ropuli...
# 8: Današnji človek se bojuje v vulgarnosti, nasilju, nemoralnosti, ubijanju, prerivanju...
#
# -----------------------
#
#
# Original sentence:
# Mladi Triglavani so po vodstvu gostov po prvem polčasu v nadaljevanju prikazali bolj učinkovito igro in zasluženo zmagali.
#
#
# Paraphrased sentences:
# 0: Mladi Triglavani so po prvem polčasu pokazali boljšo učinkovitost v igri in si zaslužili zmago.
# 1: Mladi Triglavani so po prvem polčasu pokazali bolj učinkovito igro in so zato tudi slavili.
# 2: Mladi Triglavani so po prvem polčasu pokazali več igre in so tako zasluženo zmagali.
# 3: Mladi Triglavani so po prvem polčasu pokazali učinkovitejšo igro in na koncu tudi zmagali.
# 4: Mladi Triglavani so po prvem polčasu pokazali večjo učinkovitost igre in so zato zasluženo zmagali.
# 5: Mladi Triglavani so po prvem polčasu pokazali učinkovitejšo igro in na koncu zasluženo zmago.
# 6: Mladi Triglavani so po prvem polčasu pokazali večjo učinkovitost igre in bili zasluženo zmago.
# 7: Mladi Triglavani so po prvem polčasu pokazali boljšo igro in so si zaslužili zmago.
# 8: Mladi Triglavani so po prvem polčasu pokazali učinkovitejšo igro in so si zaslužili zmago.
# 9: Mladi Triglavani so po prvem polčasu pokazali večjo učinkovitost igre in na koncu tudi zmagali.
#
# -----------------------
#
#
# Original sentence:
# Vi vplivate na druge ljudi, oni na vas.
#
#
# Paraphrased sentences:
# 0: Vi vplivate na druge ljudi, na vas.
# 1: Vi vplivate na druge ljudi, oni nanje.
#
# -----------------------
#
#
# Original sentence:
# Skrbela je za staro slepo prijateljico, ji kuhala in brala knjige.
#
#
# Paraphrased sentences:
# 0: Skrbela je za mladoletno prijateljico, kuhala in brala knjige.
# 1: Skrbela je za mlado slepo prijateljico, kuhala in brala knjige.
# 2: Skrbela je za mladoletno prijateljico, ji kuhala in brala knjige.
#
# -----------------------

# %%
# Saving paraphrases to Excel faile

output = pd.DataFrame(np.column_stack([outputTable]), 
                               columns=["Original","Parafraza 1","Parafraza 2","Parafraza 3","Parafraza 4","Parafraza 5","Parafraza 6","Parafraza 7","Parafraza 8","Parafraza 9","Parafraza 10"])

output.to_excel("/content/gdrive/MyDrive/NLPProject/paraphrasing/Paraphrases.xlsx")
